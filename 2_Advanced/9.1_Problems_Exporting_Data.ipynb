# %% [markdown]
# ## 1

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.to_csv('data_jobs_export.csv', index=False)

# %% [markdown]
# ## 2

# %%
df_filtered = df[df['job_title_short'] == 'Data Scientist']
df_filtered.to_csv('data_scientist_jobs.csv', index=False)

# %% [markdown]
# ## 3

# %%
df_filtered = df[df['job_location'] == 'New York, NY']
df_filtered.head().to_excel('new_york_jobs.xlsx', index=False) #to display it in numbers go to terminal and type: conda activate python_course and then type cd 2_Advanced and then: open new_york_jobs.xlsx
