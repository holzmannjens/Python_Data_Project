# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_filled = df
df_cleaned = df.dropna(subset='salary_year_avg')
rows_before = len(df)
rows_after = len(df_cleaned)
print(f"Rows before cleaning: {rows_before}")
print(f"Rows after cleaning: {rows_after}")
# Out:
# Rows before cleaning: 785741
# Rows after cleaning: 22003

# %%
df_filled = df
df_cleaned = df.drop_duplicates(subset='job_location')
rows_before = len(df)
rows_after = len(df_cleaned)
print(f"Rows before cleaning: {rows_before}")
print(f"Rows after cleaning: {rows_after}")
# Out:
# Rows before cleaning: 785741
# Rows after cleaning: 17218

# %%
salary_rate_before = df['salary_rate'].head(10)
df_filled = df
df_filled['salary_rate'] = df_filled['salary_rate'].fillna('Unknown')
print(salary_rate_before)
print(df_filled['salary_rate'].head(10))
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# Name: salary_rate, dtype: object
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# 5    Unknown
# 6    Unknown
# 7    Unknown
# 8    Unknown
# 9    Unknown
# Name: salary_rate, dtype: object
